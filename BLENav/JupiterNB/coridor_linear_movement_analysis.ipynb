# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data_capture_3.csv')

# %%
df = df[df.Name.str.startswith('egopi')]

# %%
len(df)
# Out:
# 195

# %%
df.Timestamp = df.Timestamp - df.Timestamp.min()

# %%
plt.plot(df.Timestamp, df.RSSI)

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
smooth_rssi_lowess = lowess(df.RSSI, df.Timestamp)

# %%
plt.plot(smooth_rssi_lowess[:, 0], smooth_rssi[:, 1])

# %%
from scipy.signal import medfilt

# %%
smooth_rssi_median = medfilt(df.RSSI, 21)

# %%
len(smooth_rssi_median)
# Out:
# 195

# %%
plt.plot(df.Timestamp, smooth_rssi_median)
